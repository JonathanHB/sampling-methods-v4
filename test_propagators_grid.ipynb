# %%
import test_propagators_grid
import importlib

# %%
importlib.reload(test_propagators_grid)
print("1D CV test")
test_propagators_grid.test_propagators_grid_1d_cv()
print("2D CV test")
test_propagators_grid.test_propagators_grid_2d_cv()
# Out:
# 1D CV test
# trajectories shape (4, 3000, 2)
# potentials shape (4, 300, 81)
# sample final coords [[-0.50743099 -1.46926556]
#  [-2.31322455 -1.56772088]
#  [-2.50699554 -1.5585567 ]
#  [ 1.92507823  1.35978797]]
# True True
# (2,)
# (2,)
# /home/jonathan/Documents/grabelab/sampling-scheme-development/sampling-methods-v4/test_propagators_grid.py:145: RuntimeWarning: divide by zero encountered in log
#   plt.plot(cv_grid, -kT*np.log(pops_1d[0]/np.sum(pops_1d[0])), label = "importance sampling FE estimate")
# 2D CV test
# 2cv trajectories shape (4, 3000, 2)
# 2cv potentials shape (4, 300, 25, 25)
# True True
# note that different-dimensional CVs may require different omega values to be effective, (copilot: 'and the bias potential may not be as smooth in higher dimensions due to fewer samples per grid point').

# %%
importlib.reload(test_propagators_grid)
print("1D CV test shared grid")
test_propagators_grid.test_propagators_grid_1d_cv_shared_grid()
print("2D CV test shared grid")
test_propagators_grid.test_propagators_grid_2d_cv_shared_grid()
# Out:
# 1D CV test shared grid
# trajectories shape (4, 3000, 2)
# potentials shape (300, 81)
# sample final coords [[ 1.74082617  1.40138515]
#  [ 1.31160441  1.41688634]
#  [ 2.06651089  1.8821543 ]
#  [-1.27956085 -1.47601114]]
# True True
# (2,)
# (2,)
# 2D CV test shared grid
# 2cv trajectories shape (4, 3000, 2)
# 2cv potentials shape (300, 25, 25)
# True True
# note that different-dimensional CVs may require different omega values to be effective, (copilot: 'and the bias potential may not be as smooth in higher dimensions due to fewer samples per grid point').
