# %%
import numpy as np
import matplotlib.pyplot as plt
import collective_variables
import energy_landscapes
from propagators_grid import propagate
import visualization
import collective_variable_analysis
import importlib

# %%
importlib.reload(collective_variables)
importlib.reload(collective_variable_analysis)

T=1
kB=1
kT = kB*T

sim_system = energy_landscapes.diagonal_2well_2d_system

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT = kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
plt.savefig("figures/diagonal_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=None, slice_axis=0, name = "diagonal_FE")

macro_FE = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE} kT")
# Out:
# Macrostate delta G = -1.8762685431541035e-06 kT

# %%
T=1
kB=1
kT = kB*T

sim_system = energy_landscapes.cv0_2well_2d_system

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT = kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
plt.savefig("figures/straight_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=None, slice_axis=0, name = "straight_FE")

macro_FE = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE} kT")
# Out:
# Macrostate delta G = -1.7659443952194226e-05 kT

# %%
importlib.reload(energy_landscapes)

T=1
kB=1
kT = kB*T

sim_system = energy_landscapes.decoupled_4well_2d_system

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT = kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
#plt.savefig("figures/diagonal_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=None, slice_axis=0, name = "diagonal_FE")

macro_FE = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE} kT")
# Out:
# Macrostate delta G = -1.7659443952194226e-05 kT

# %%
importlib.reload(energy_landscapes)
importlib.reload(collective_variables)
importlib.reload(collective_variable_analysis)
importlib.reload(visualization)

T=1
kB=1
kT=kB*T

sim_system = energy_landscapes.coupled_4well_2d_system

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT=kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
#plt.savefig("figures/diagonal_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=[-2,-2], slice_axis=0, name = "diagonal_FE")

macro_FE_1d = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE_1d} kT")


macro_FE_2d = collective_variable_analysis.macrostate_delta_g_v2(sim_system, 
                                                              collective_variables.cv_null_2d, 
                                                              collective_variables.macrostate_classifier_cv01_eq0, 
                                                              kT)

print(f"Macrostate G = {macro_FE_2d} kT")
print(f"Macrostate delta G where (x1 ~= -2) = {macro_FE_2d[0]- macro_FE_2d[1]}")

visualization.plot_G_surface(sim_system.G, 
                             x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), 
                             n=200, center=[-2,-2], slice_axis=0, name = "diagonal_FE",
                             add_CV_FE=True,
                             CV=CV,
                             sim_system=sim_system,
                             kT=1.0
    )
# Out:
# Macrostate delta G = -1.7664237470096528e-06 kT
# Macrostate G = [-7.07225793 -1.44724332 -1.45001218 -7.07224616] kT
# Macrostate delta G where (x1 ~= -2) = -5.625014610830952

# %%
importlib.reload(energy_landscapes)
importlib.reload(collective_variables)
importlib.reload(collective_variable_analysis)
importlib.reload(visualization)

T=1
kB=1
kT=kB*T

sim_system = energy_landscapes.coupled_4well_2d_system_v2

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT=kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
#plt.savefig("figures/diagonal_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=[-2,-2], slice_axis=0, name = "diagonal_FE")

macro_FE_1d = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE_1d} kT")


macro_FE_2d = collective_variable_analysis.macrostate_delta_g_v2(sim_system, 
                                                              collective_variables.cv_null_2d, 
                                                              collective_variables.macrostate_classifier_cv01_eq0, 
                                                              kT)

print(f"Macrostate G = {macro_FE_2d} kT")
print(f"Macrostate delta G where (x1 ~= -2) = {macro_FE_2d[0]- macro_FE_2d[1]}")

visualization.plot_G_surface(sim_system.G, 
                             x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), 
                             n=200, center=[-2,-2], slice_axis=0, name = "diagonal_FE",
                             add_CV_FE=True,
                             CV=CV,
                             sim_system=sim_system,
                             kT=1.0
    )
# Out:
# Macrostate delta G = 0.23945395205478273 kT
# Macrostate G = [-7.41971047 -1.86344847 -1.97135293 -7.6596405 ] kT
# Macrostate delta G where (x1 ~= -2) = -5.556262002052748

# %%
importlib.reload(energy_landscapes)
importlib.reload(collective_variables)
importlib.reload(collective_variable_analysis)

T=1
kB=1
kT = kB*T

sim_system = energy_landscapes.unfoldable_4well_2d_system

CV = collective_variables.cv_coord0_2d_coord_1d_cv

cv_grid, free_energy_grid = collective_variable_analysis.free_energy_on_cv_grid(
        free_energy_fn=sim_system.G,
        coord_min=sim_system.coord_min,
        coord_max=sim_system.coord_max,
        n_micro_grid=sim_system.grid_n,
        cv_fn=CV.cv_funct,
        cv_min=CV.cv_min,
        cv_max=CV.cv_max,
        n_cv_grid=CV.grid_n,
        kT = kT
    )

plt.plot(cv_grid, free_energy_grid)
plt.xlabel('CV=x0')
plt.ylabel('Free Energy (kT)')
#plt.savefig("figures/diagonal_CV_FE.png", dpi=600)

visualization.plot_G_surface(sim_system.G, x_limits = ((sim_system.coord_min[0], sim_system.coord_max[0]), (sim_system.coord_min[1], sim_system.coord_max[1])), n=200, center=None, slice_axis=0, name = "diagonal_FE")

macro_FE = collective_variable_analysis.macrostate_delta_g(sim_system, CV, collective_variables.macrostate_classifier_cv0_eq0, kT)
print(f"Macrostate delta G = {macro_FE} kT")


macro_FE = collective_variable_analysis.macrostate_delta_g_v2(sim_system, 
                                                              collective_variables.cv_null_2d, 
                                                              collective_variables.macrostate_classifier_cv01_eq0, 
                                                              kT)
print(f"Macrostate G = {macro_FE} kT")
# Out:
# Macrostate delta G = -0.003982604798032749 kT
# Macrostate G = [-6.78482889 -1.65294786 -0.52947307 -6.78481603] kT

# %%
x = np.linspace(-1,1,100)
y = 4*(2.5*x**2-1)**2
plt.plot(x,y, linewidth = "4")

plt.xlim(-1,1)
plt.xticks((-1,-0.5,0,0.5,1),(-1,-0.5,0,0.5,1), fontsize=14)
plt.ylim(-0.1,8)
plt.yticks((0,2,4,6,8),(0,2,4,6,8), fontsize=14)

plt.xlabel("CV", fontsize=16)
plt.ylabel("Energy", fontsize=16)
plt.savefig("figures/example_2_well_landscape.png", dpi=600)
