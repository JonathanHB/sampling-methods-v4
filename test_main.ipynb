# %%
import importlib
import main
import simulator_classes
import propagators_grid
import weighted_ensemble_v2
import estimate_observables
import make_figures
import collective_variables
import set_params

# %%
importlib.reload(main)
importlib.reload(simulator_classes)
importlib.reload(propagators_grid)
importlib.reload(weighted_ensemble_v2)
importlib.reload(estimate_observables)
importlib.reload(make_figures)
importlib.reload(collective_variables)
importlib.reload(set_params)

main.multiplot_main_variable_WE()
# Out:
# t_f, t_g
# 0.005582234338711697 0.05582234338711697
# n_steps_per_frame=1
# n_frames_per_gaussian=10
# -- running condition 1 of 5
# with n_gaussians_per_round = 1
# with n_we_rounds = 896
# running replicate 1 of 3
# /home/jonathan/Documents/grabelab/sampling-scheme-development/sampling-methods-v4/estimate_observables.py:68: RuntimeWarning: divide by zero encountered in double_scalars
#   delta_G[we_i] = -np.log((1-pop_state_A)/pop_state_A)
# molecular length = 8960 frames
# running replicate 2 of 3
# molecular length = 8960 frames
# running replicate 3 of 3
# molecular length = 8960 frames
# -- running condition 2 of 5
# with n_gaussians_per_round = 112
# with n_we_rounds = 8
# running replicate 1 of 3
# molecular length = 8960 frames
# running replicate 2 of 3
# molecular length = 8960 frames
# running replicate 3 of 3
# /home/jonathan/Documents/grabelab/sampling-scheme-development/sampling-methods-v4/estimate_observables.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   delta_G[tp] = -np.log((1-pop_state_A)/pop_state_A)
# molecular length = 8960 frames
# -- running condition 3 of 5
# with n_gaussians_per_round = 224
# with n_we_rounds = 4
# running replicate 1 of 3
# molecular length = 8960 frames
# running replicate 2 of 3
# molecular length = 8960 frames
# running replicate 3 of 3
# molecular length = 8960 frames
# -- running condition 4 of 5
# with n_gaussians_per_round = 448
# with n_we_rounds = 2
# running replicate 1 of 3
# molecular length = 8960 frames
# running replicate 2 of 3
# molecular length = 8960 frames
# running replicate 3 of 3
# molecular length = 8960 frames
# -- running condition 5 of 5
# with n_gaussians_per_round = 896
# with n_we_rounds = 1
# running replicate 1 of 3
# molecular length = 8960 frames
# running replicate 2 of 3
# molecular length = 8960 frames
# running replicate 3 of 3
# molecular length = 8960 frames

# %%
#10560*0.005

# %%
# import numpy as np
# a = np.ones((2,2))
# print(a)
# print(np.concatenate([a]))
