# %%
import importlib
import main
import simulator_classes
import propagators_grid
import weighted_ensemble_v2
import estimate_observables
import make_figures
import collective_variables
import set_params
import energy_landscapes

# %%
importlib.reload(main)
importlib.reload(simulator_classes)
importlib.reload(propagators_grid)
importlib.reload(weighted_ensemble_v2)
importlib.reload(estimate_observables)
importlib.reload(make_figures)
importlib.reload(collective_variables)
importlib.reload(set_params)
importlib.reload(energy_landscapes)

main.multiplot_main_variable_WE()
# Out:
# t_f, t_g
# 0.005477990720343653 0.054779907203436534
# n_steps_per_frame=1
# n_frames_per_gaussian=10
# -- running condition 1 of 7
# with n_gaussians_per_round = 3651
# running replicate 1 of 5
# used 1156640 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1156640 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1156640 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1156640 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1156640 datapoints
# used 1168300 datapoints
# -- running condition 2 of 7
# with n_gaussians_per_round = 913
# running replicate 1 of 5
# used 1770410 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1715660 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1496660 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1825160 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1715660 datapoints
# used 1168300 datapoints
# -- running condition 3 of 7
# with n_gaussians_per_round = 228
# running replicate 1 of 5
# used 1570416 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1591332 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1566912 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1751988 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1857132 datapoints
# used 1168300 datapoints
# -- running condition 4 of 7
# with n_gaussians_per_round = 57
# running replicate 1 of 5
# used 1313622 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1330380 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1293444 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1394028 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1460340 datapoints
# used 1168300 datapoints
# -- running condition 5 of 7
# with n_gaussians_per_round = 14
# running replicate 1 of 5
# used 1253242 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1250476 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1216630 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1188910 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1246624 datapoints
# used 1168300 datapoints
# -- running condition 6 of 7
# with n_gaussians_per_round = 4
# running replicate 1 of 5
# used 1178234 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1279856 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1172846 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1158008 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1191914 datapoints
# used 1168300 datapoints
# -- running condition 7 of 7
# with n_gaussians_per_round = 1
# running replicate 1 of 5
# used 1126316 datapoints
# used 1168300 datapoints
# running replicate 2 of 5
# used 1129700 datapoints
# used 1168300 datapoints
# running replicate 3 of 5
# used 1118456 datapoints
# used 1168300 datapoints
# running replicate 4 of 5
# used 1126676 datapoints
# used 1168300 datapoints
# running replicate 5 of 5
# used 1129052 datapoints
# used 1168300 datapoints

# %%
#10560*0.005

# %%
# import numpy as np
# a = np.ones((2,2))
# print(a)
# # print(np.concatenate([a]))
# import matplotlib.pyplot as plt
# a=1
# plt.xlabel(r"$t_{WE}$={a}")
# plt.show()

# %%
# a=1
# plt.xlabel(f'$t_{{WE}}$={a}')
# plt.show()
