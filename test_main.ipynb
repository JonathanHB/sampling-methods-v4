# %%
import importlib
import main
import simulator_classes
import propagators_grid
import weighted_ensemble_v2
import estimate_observables
import make_figures
import collective_variables
import set_params

# %%
importlib.reload(main)
importlib.reload(simulator_classes)
importlib.reload(propagators_grid)
importlib.reload(weighted_ensemble_v2)
importlib.reload(estimate_observables)
importlib.reload(make_figures)
importlib.reload(collective_variables)
importlib.reload(set_params)

main.multiplot_main_variable_WE()
# Out:
# t_f, t_g
# 0.005247110698865317 0.05247110698865318
# n_steps_per_frame=1
# n_frames_per_gaussian=10
# -- running condition 1 of 5
# with n_gaussians_per_round = 1906
# running replicate 1 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 1 >= 1 after 0 WE rounds
# molecular time = 19060 frames
# aggregate time = 609920 frames
# used 609856 datapoints
# running replicate 2 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 1 >= 1 after 0 WE rounds
# molecular time = 19060 frames
# aggregate time = 609920 frames
# used 609856 datapoints
# running replicate 3 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 1 >= 1 after 0 WE rounds
# molecular time = 19060 frames
# aggregate time = 609920 frames
# used 609856 datapoints
# -- running condition 2 of 5
# with n_gaussians_per_round = 476
# running replicate 1 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 5 >= 4 after 1 WE rounds
# molecular time = 9520 frames
# aggregate time = 723520 frames
# used 701680 datapoints
# running replicate 2 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 5 >= 4 after 1 WE rounds
# molecular time = 9520 frames
# aggregate time = 694960 frames
# used 674212 datapoints
# running replicate 3 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 6 >= 4 after 1 WE rounds
# molecular time = 9520 frames
# aggregate time = 809200 frames
# used 784084 datapoints
# -- running condition 3 of 5
# with n_gaussians_per_round = 119
# running replicate 1 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 19 >= 17 after 4 WE rounds
# molecular time = 5950 frames
# aggregate time = 644980 frames
# used 637672 datapoints
# running replicate 2 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 19 >= 17 after 6 WE rounds
# molecular time = 8330 frames
# aggregate time = 659260 frames
# used 647920 datapoints
# running replicate 3 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 17 >= 17 after 5 WE rounds
# molecular time = 7140 frames
# aggregate time = 559300 frames
# used 551290 datapoints
# -- running condition 4 of 5
# with n_gaussians_per_round = 30
# running replicate 1 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 69 >= 67 after 25 WE rounds
# molecular time = 7800 frames
# aggregate time = 519000 frames
# used 507318 datapoints
# running replicate 2 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 67 >= 67 after 23 WE rounds
# molecular time = 7200 frames
# aggregate time = 479400 frames
# used 468672 datapoints
# running replicate 3 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 67 >= 67 after 24 WE rounds
# molecular time = 7500 frames
# aggregate time = 486600 frames
# used 481374 datapoints
# -- running condition 5 of 5
# with n_gaussians_per_round = 7
# running replicate 1 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 286 >= 286 after 124 WE rounds
# molecular time = 8750 frames
# aggregate time = 523880 frames
# used 514700 datapoints
# running replicate 2 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 287 >= 286 after 122 WE rounds
# molecular time = 8610 frames
# aggregate time = 511700 frames
# used 509456 datapoints
# running replicate 3 of 3
# reached the maximum number of gpu (and hence WE) rounds permitted by the WE round length, number of GPUs, and wall clock time limit 287 >= 286 after 121 WE rounds
# molecular time = 8540 frames
# aggregate time = 521360 frames
# used 512540 datapoints

# %%
#10560*0.005

# %%
# import numpy as np
# a = np.ones((2,2))
# print(a)
# print(np.concatenate([a]))
