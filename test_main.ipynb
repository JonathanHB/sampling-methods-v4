# %%
import importlib
import main
import simulator_classes
import propagators_grid
import weighted_ensemble_v2
import estimate_observables
import make_figures
import collective_variables
import set_params
import energy_landscapes

# %%
importlib.reload(main)
importlib.reload(simulator_classes)
importlib.reload(propagators_grid)
importlib.reload(weighted_ensemble_v2)
importlib.reload(estimate_observables)
importlib.reload(make_figures)
importlib.reload(collective_variables)
importlib.reload(set_params)
importlib.reload(energy_landscapes)

main.multiplot_main_variable_WE()
# Out:
# t_f, t_g
# 0.004098791116184058 0.040987911161840584
# n_steps_per_frame=1
# n_frames_per_gaussian=10
# -- running condition 1 of 7
# with n_gaussians_per_round = 4879
# running replicate 1 of 5
# used 1545824 datapoints
# used 1545786 datapoints
# running replicate 2 of 5
# used 1545824 datapoints
# used 1545786 datapoints
# running replicate 3 of 5
# used 1545824 datapoints
# used 1545786 datapoints
# running replicate 4 of 5
# used 1545824 datapoints
# used 1545786 datapoints
# running replicate 5 of 5
# used 1545824 datapoints
# used 1545786 datapoints
# -- running condition 2 of 7
# with n_gaussians_per_round = 1220
# running replicate 1 of 5
# used 2293288 datapoints
# used 1561400 datapoints
# running replicate 2 of 5
# used 2293288 datapoints
# used 1561400 datapoints
# running replicate 3 of 5
# used 2293288 datapoints
# used 1561400 datapoints
# running replicate 4 of 5
# used 2146912 datapoints
# used 1561400 datapoints
# running replicate 5 of 5
# used 2220100 datapoints
# used 1561400 datapoints
# -- running condition 3 of 7
# with n_gaussians_per_round = 305
# running replicate 1 of 5
# used 1229014 datapoints
# used 1311576 datapoints
# running replicate 2 of 5
# used 1174114 datapoints
# used 1264734 datapoints
# running replicate 3 of 5
# used 2402986 datapoints
# used 1561400 datapoints
# running replicate 4 of 5
# used 2402992 datapoints
# used 1561400 datapoints
# running replicate 5 of 5
# used 1245112 datapoints
# used 1327190 datapoints
# -- running condition 4 of 7
# with n_gaussians_per_round = 76
# running replicate 1 of 5
# used 1450490 datapoints
# used 1530172 datapoints
# running replicate 2 of 5
# used 1142480 datapoints
# used 1311576 datapoints
# running replicate 3 of 5
# used 1178960 datapoints
# used 1342804 datapoints
# running replicate 4 of 5
# used 1463330 datapoints
# used 1545786 datapoints
# running replicate 5 of 5
# used 1461470 datapoints
# used 1545786 datapoints
# -- running condition 5 of 7
# with n_gaussians_per_round = 19
# running replicate 1 of 5
# used 1170356 datapoints
# used 1295962 datapoints
# running replicate 2 of 5
# used 1190264 datapoints
# used 1327190 datapoints
# running replicate 3 of 5
# used 1223540 datapoints
# used 1280348 datapoints
# running replicate 4 of 5
# used 1211792 datapoints
# used 1342804 datapoints
# running replicate 5 of 5
# used 1331720 datapoints
# used 1342804 datapoints
# -- running condition 6 of 7
# with n_gaussians_per_round = 5
# running replicate 1 of 5
# used 1111432 datapoints
# used 1280348 datapoints
# running replicate 2 of 5
# used 1208584 datapoints
# used 1280348 datapoints
# running replicate 3 of 5
# used 1152160 datapoints
# used 1280348 datapoints
# running replicate 4 of 5
# used 1121008 datapoints
# used 1280348 datapoints
# running replicate 5 of 5
# used 1148260 datapoints
# used 1280348 datapoints
# -- running condition 7 of 7
# with n_gaussians_per_round = 1
# running replicate 1 of 5
# used 1071020 datapoints
# used 1280348 datapoints
# running replicate 2 of 5
# used 1280144 datapoints
# used 1280348 datapoints
# running replicate 3 of 5
# used 1074500 datapoints
# used 1280348 datapoints
# running replicate 4 of 5
# used 1071740 datapoints
# used 1280348 datapoints
# running replicate 5 of 5
# used 1073360 datapoints
# used 1280348 datapoints

# %%
#10560*0.005

# %%
# import numpy as np
# a = np.ones((2,2))
# print(a)
# # print(np.concatenate([a]))
# import matplotlib.pyplot as plt
# a=1
# plt.xlabel(r"$t_{WE}$={a}")
# plt.show()

# %%
# a=1
# plt.xlabel(f'$t_{{WE}}$={a}')
# plt.show()
